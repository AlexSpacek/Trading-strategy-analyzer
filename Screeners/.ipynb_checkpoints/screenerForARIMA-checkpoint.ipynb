# %% [markdown]
# # Single analysis notebook
#
# This notebook aims to create enviroment to simply test strategies developed in Stocks & Loss system for python

# %%
# imports 
import sys, os.path
root_dir = (os.path.abspath(os.path.join(os.path.abspath(''), '..')))
sys.path.append(root_dir)
from scraper import stock_daily
from analyzer import Analyzer
from IPython.display import display
import pandas as pd
import datetime as dt
import numpy as np
import matplotlib.pyplot as plt
import indicators as ind
import warnings
import pmdarima.arima as arm

warnings.filterwarnings('ignore')

# %% [markdown]
# ## Settings
# * Select stock ticker
# * Define buy and sell strategy (buystrat and sellstrat)
# * Define if you want to run stop loss and what value
# * Same with profit taker

# %%
xls = pd.ExcelFile((os.path.abspath(os.path.join(os.path.abspath(''), '..'))) + '/Data/IWM_top600.xls')
# stop loss
sl = True
slval = 0.04
# profit taker
pt = False
ptval = 0.2
# repeteated buys
rb = False

# %% [markdown]
# ## Running calculation

# %%
chosen = pd.DataFrame()
fundTickers = pd.DataFrame()
Tickers = pd.DataFrame()
fundTickers["Fund/sector name"] = xls.sheet_names
# print(fundTickers)
# Tickers = pd.DataFrame(,columns=funTickers["Index fund name"])
for i in range(len(xls.sheet_names)):
    sheet1 = pd.read_excel(xls, i)
    # print(sheet1)
    fundTickers.loc[i,["Fund/sector ticker"]] = sheet1.columns[1]
    Tickers[fundTickers.loc[i,["Fund/sector name"]]] = sheet1[sheet1.columns[1]][0:]
    # print(Tickers)
pd.set_option('display.expand_frame_repr', False)    
# display(Tickers)
# I have the initialization here on purpose, to measure its impact
col = ["Ticker", "Trades", "Good trades", "Profit[%]", "Profit[$]", "Hold[%]"]
results = [None] * Tickers.columns.shape[0]
for k in range(Tickers.columns.shape[0]):
    # when I tried to initialize results as [dataframe] * 10 it created list of identical dataframes and when i changed one, it changed them all. Interesting
    results[k] = pd.DataFrame(data=np.zeros([Tickers.shape[0], len(col)]),columns=col)
# iterate over columns
i = 0 
for label, tic in Tickers.iteritems():
    # print(label)
    # print(Tickers)
    # iterate over items in sectors / indexes
    for j, val in tic.iteritems():
        # j starts at 1, instead of usual 0 => reason why there is -1 everywhere
        # analyze stock
        # print("print")
        print(j)
        try:
            stock = stock_daily(val, save=False)
            trades = Analyzer(ticker=val,data=stock.data)
            # fig=plt.figure()
            # plt.plot(stock.data["Close"], color="b")
            # plt.show()
            # adf_test = arm.ADFTest(alpha = 0.05)
            # print(adf_test.should_diff(stock.data["Close"][-100:]))
            train_0 = stock.data["Close"][-200:]
            train_1 = train_0.reset_index()
            train = train_1["Close"]
            # print(train.values)
            model = arm.auto_arima(train.values, start_p=10, start_q=10,
                      test='adf',       # use adftest to find optimal 'd'
                      max_p=20, max_q=20, # maximum p and q
                      m=1,              # frequency of series
                      d=None,           # let model determine 'd'
                      seasonal=False,   # No Seasonality
                      start_P=0, 
                      D=0, 
                      trace=True,
                      random=False,
                      error_action='ignore',  
                      suppress_warnings=True, 
                      stepwise=False)
            n_periods = 20
            fc, confint = model.predict(n_periods=n_periods, return_conf_int=True,alpha=0.05)
            index_of_fc = np.arange(len(train), len(train)+n_periods)
            fc_series = pd.Series(fc, index=index_of_fc)
            lower_series = pd.Series(confint[:, 0], index=index_of_fc)
            upper_series = pd.Series(confint[:, 1], index=index_of_fc)
            compare = stock.data["Close"][-200:].reset_index()
            AbsReward=confint[-1, 1]
            AbsRisk=confint[-1, 0]
            BuyPrice=compare["Close"].iloc[-1]
            Risk=(BuyPrice-AbsRisk)/BuyPrice*100
            Reward=(AbsReward-BuyPrice)/BuyPrice*100
            RR=Reward/Risk
            if RR>1.5:
                chosen = chosen.append({"R/R": RR,"Ticker": stock.ticker}, ignore_index=True)                  
        except:
            results[i].loc[j-1,["Ticker"]] = val
# Out:
# 0
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=
sec
#  ARIMA(1,1,4)(0,0,0)[0] intercept   : AIC=460.120, Time=0.60 sec
#  ARIMA(2,1,0)(0,0,0)[0] intercept   : AIC=454.508, Time=0.07 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=455.883, Time=0.25 sec
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=457.844, Time=0.35 sec
#  ARIMA(2,1,3)(0,0,0)[0] intercept   : AIC=inf, Time=0.47 sec
#  ARIMA(3,1,0)(0,0,0)[0] intercept   : AIC=456.445, Time=0.06 sec
#  ARIMA(3,1,1)(0,0,0)[0] intercept   : AIC=457.842, Time=0.24 sec
#  ARIMA(3,1,2)(0,0,0)[0] intercept   : AIC=459.760, Time=0.43 sec
#  ARIMA(4,1,0)(0,0,0)[0] intercept   : AIC=458.109, Time=0.07 sec
#  ARIMA(4,1,1)(0,0,0)[0] intercept   : AIC=460.102, Time=0.20 sec
#  ARIMA(5,1,0)(0,0,0)[0] intercept   : AIC=460.106, Time=0.09 sec
#
# Best model:  ARIMA(1,1,0)(0,0,0)[0] intercept
# Total fit time: 4.173 seconds
# 596
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=-47.000, Time=0.03 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=-45.791, Time=0.06 sec
#  ARIMA(0,1,2)(0,0,0)[0] intercept   : AIC=-44.170, Time=0.07 sec
#  ARIMA(0,1,3)(0,0,0)[0] intercept   : AIC=-42.331, Time=0.12 sec
#  ARIMA(0,1,4)(0,0,0)[0] intercept   : AIC=-40.814, Time=0.15 sec
#  ARIMA(0,1,5)(0,0,0)[0] intercept   : AIC=-39.499, Time=0.30 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=-45.711, Time=0.06 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=-43.962, Time=0.06 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=-42.212, Time=0.19 sec
#  ARIMA(1,1,3)(0,0,0)[0] intercept   : AIC=-40.171, Time=0.11 sec
#  ARIMA(1,1,4)(0,0,0)[0] intercept   : AIC=-38.736, Time=0.42 sec
#  ARIMA(2,1,0)(0,0,0)[0] intercept   : AIC=-44.278, Time=0.06 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=-42.300, Time=0.23 sec
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.45 sec
#  ARIMA(2,1,3)(0,0,0)[0] intercept   : AIC=inf, Time=0.50 sec
#  ARIMA(3,1,0)(0,0,0)[0] intercept   : AIC=-42.352, Time=0.15 sec
#  ARIMA(3,1,1)(0,0,0)[0] intercept   : AIC=-40.493, Time=0.33 sec
#  ARIMA(3,1,2)(0,0,0)[0] intercept   : AIC=-47.754, Time=0.47 sec
#  ARIMA(4,1,0)(0,0,0)[0] intercept   : AIC=-41.040, Time=0.10 sec
#  ARIMA(4,1,1)(0,0,0)[0] intercept   : AIC=-39.209, Time=0.37 sec
#  ARIMA(5,1,0)(0,0,0)[0] intercept   : AIC=-39.516, Time=0.16 sec
#
# Best model:  ARIMA(3,1,2)(0,0,0)[0] intercept
# Total fit time: 4.420 seconds
# 597
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=-348.017, Time=0.02 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=-346.383, Time=0.06 sec
#  ARIMA(0,1,2)(0,0,0)[0] intercept   : AIC=-345.847, Time=0.08 sec
#  ARIMA(0,1,3)(0,0,0)[0] intercept   : AIC=-343.918, Time=0.11 sec
#  ARIMA(0,1,4)(0,0,0)[0] intercept   : AIC=-341.935, Time=0.20 sec
#  ARIMA(0,1,5)(0,0,0)[0] intercept   : AIC=-340.097, Time=0.35 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=-346.319, Time=0.03 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=-344.942, Time=0.21 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=-343.905, Time=0.09 sec
#  ARIMA(1,1,3)(0,0,0)[0] intercept   : AIC=-342.250, Time=0.47 sec
#  ARIMA(1,1,4)(0,0,0)[0] intercept   : AIC=-341.565, Time=0.43 sec
#  ARIMA(2,1,0)(0,0,0)[0] intercept   : AIC=-345.884, Time=0.06 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=-343.901, Time=0.11 sec
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=-341.914, Time=0.30 sec
#  ARIMA(2,1,3)(0,0,0)[0] intercept   : AIC=-339.919, Time=0.45 sec
#  ARIMA(3,1,0)(0,0,0)[0] intercept   : AIC=-343.897, Time=0.09 sec
#  ARIMA(3,1,1)(0,0,0)[0] intercept   : AIC=-341.896, Time=0.10 sec
#  ARIMA(3,1,2)(0,0,0)[0] intercept   : AIC=-339.910, Time=0.22 sec
#  ARIMA(4,1,0)(0,0,0)[0] intercept   : AIC=-341.921, Time=0.12 sec
#  ARIMA(4,1,1)(0,0,0)[0] intercept   : AIC=-339.919, Time=0.19 sec
#  ARIMA(5,1,0)(0,0,0)[0] intercept   : AIC=-340.023, Time=0.17 sec
#
# Best model:  ARIMA(0,1,0)(0,0,0)[0] intercept
# Total fit time: 3.857 seconds
# 598
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=658.410, Time=0.01 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=653.314, Time=0.03 sec
#  ARIMA(0,1,2)(0,0,0)[0] intercept   : AIC=655.124, Time=0.04 sec
#  ARIMA(0,1,3)(0,0,0)[0] intercept   : AIC=652.154, Time=0.05 sec
#  ARIMA(0,1,4)(0,0,0)[0] intercept   : AIC=653.190, Time=0.08 sec
#  ARIMA(0,1,5)(0,0,0)[0] intercept   : AIC=654.904, Time=0.09 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=652.806, Time=0.03 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=654.298, Time=0.06 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=656.298, Time=0.11 sec
#  ARIMA(1,1,3)(0,0,0)[0] intercept   : AIC=653.483, Time=0.12 sec
#  ARIMA(1,1,4)(0,0,0)[0] intercept   : AIC=654.565, Time=0.17 sec
#  ARIMA(2,1,0)(0,0,0)[0] intercept   : AIC=654.498, Time=0.05 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=656.298, Time=0.14 sec
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.41 sec
#  ARIMA(2,1,3)(0,0,0)[0] intercept   : AIC=655.339, Time=0.25 sec
#  ARIMA(3,1,0)(0,0,0)[0] intercept   : AIC=654.924, Time=0.05 sec
#  ARIMA(3,1,1)(0,0,0)[0] intercept   : AIC=654.499, Time=0.15 sec
#  ARIMA(3,1,2)(0,0,0)[0] intercept   : AIC=655.969, Time=0.21 sec
#  ARIMA(4,1,0)(0,0,0)[0] intercept   : AIC=652.741, Time=0.07 sec
#  ARIMA(4,1,1)(0,0,0)[0] intercept   : AIC=654.621, Time=0.17 sec
#  ARIMA(5,1,0)(0,0,0)[0] intercept   : AIC=654.651, Time=0.10 sec
#
# Best model:  ARIMA(0,1,3)(0,0,0)[0] intercept
# Total fit time: 2.429 seconds
# 599
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=-6.393, Time=0.04 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=-5.766, Time=0.06 sec
#  ARIMA(0,1,2)(0,0,0)[0] intercept   : AIC=-3.880, Time=0.09 sec
#  ARIMA(0,1,3)(0,0,0)[0] intercept   : AIC=-2.278, Time=0.09 sec
#  ARIMA(0,1,4)(0,0,0)[0] intercept   : AIC=-1.227, Time=0.20 sec
#  ARIMA(0,1,5)(0,0,0)[0] intercept   : AIC=-1.541, Time=0.25 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=-5.828, Time=0.04 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=-4.053, Time=0.22 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=-2.280, Time=0.24 sec
#  ARIMA(1,1,3)(0,0,0)[0] intercept   : AIC=inf, Time=0.44 sec
#  ARIMA(1,1,4)(0,0,0)[0] intercept   : AIC=-2.444, Time=0.48 sec
#  ARIMA(2,1,0)(0,0,0)[0] intercept   : AIC=-3.928, Time=0.06 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=-2.277, Time=0.23 sec
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.40 sec
#  ARIMA(2,1,3)(0,0,0)[0] intercept   : AIC=inf, Time=0.46 sec
#  ARIMA(3,1,0)(0,0,0)[0] intercept   : AIC=-2.163, Time=0.07 sec
#  ARIMA(3,1,1)(0,0,0)[0] intercept   : AIC=-4.389, Time=0.39 sec
#  ARIMA(3,1,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.42 sec
#  ARIMA(4,1,0)(0,0,0)[0] intercept   : AIC=-0.640, Time=0.12 sec
#  ARIMA(4,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.48 sec
#  ARIMA(5,1,0)(0,0,0)[0] intercept   : AIC=-0.754, Time=0.21 sec
#
# Best model:  ARIMA(0,1,0)(0,0,0)[0] intercept
# Total fit time: 4.985 seconds
# 600
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=490.151, Time=0.03 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=492.144, Time=0.04 sec
#  ARIMA(0,1,2)(0,0,0)[0] intercept   : AIC=494.049, Time=0.05 sec
#  ARIMA(0,1,3)(0,0,0)[0] intercept   : AIC=495.890, Time=0.15 sec
#  ARIMA(0,1,4)(0,0,0)[0] intercept   : AIC=497.356, Time=0.08 sec
#  ARIMA(0,1,5)(0,0,0)[0] intercept   : AIC=499.262, Time=0.09 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=492.144, Time=0.04 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=494.150, Time=0.04 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=496.022, Time=0.20 sec
#  ARIMA(1,1,3)(0,0,0)[0] intercept   : AIC=inf, Time=0.49 sec
#  ARIMA(1,1,4)(0,0,0)[0] intercept   : AIC=499.281, Time=0.20 sec
#  ARIMA(2,1,0)(0,0,0)[0] intercept   : AIC=494.062, Time=0.05 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.32 sec
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.43 sec
#  ARIMA(2,1,3)(0,0,0)[0] intercept   : AIC=inf, Time=0.53 sec
#  ARIMA(3,1,0)(0,0,0)[0] intercept   : AIC=495.916, Time=0.05 sec
#  ARIMA(3,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.40 sec
#  ARIMA(3,1,2)(0,0,0)[0] intercept   : AIC=495.728, Time=0.44 sec
#  ARIMA(4,1,0)(0,0,0)[0] intercept   : AIC=497.434, Time=0.07 sec
#  ARIMA(4,1,1)(0,0,0)[0] intercept   : AIC=499.290, Time=0.21 sec
#  ARIMA(5,1,0)(0,0,0)[0] intercept   : AIC=499.248, Time=0.09 sec
#
# Best model:  ARIMA(0,1,0)(0,0,0)[0] intercept
# Total fit time: 4.023 seconds

# %%
# print(model.summary())

# %%
# model.plot_diagnostics(figsize=(7,5))
# plt.show()

# %%
tickerInput="CF"


#Forcast one STICKER
stock = stock_daily(tickerInput, save=False)
trades = Analyzer(ticker=val,data=stock.data)
train_0 = stock.data["Close"][-200:]
train_1 = train_0.reset_index()
train = train_1["Close"]
model = arm.auto_arima(train.values, start_p=10, start_q=10,
                      test='adf',       # use adftest to find optimal 'd'
                      max_p=20, max_q=20, # maximum p and q
                      m=1,              # frequency of series
                      d=None,           # let model determine 'd'
                      seasonal=False,   # No Seasonality
                      start_P=0, 
                      D=0, 
                      trace=True,
                      random=False,
                      error_action='ignore',  
                      suppress_warnings=True, 
                      stepwise=False)
# Forecast
n_periods = 20
fc, confint = model.predict(n_periods=n_periods, return_conf_int=True,alpha=0.05)
index_of_fc = np.arange(len(train), len(train)+n_periods)

# make series for plotting purpose
fc_series = pd.Series(fc, index=index_of_fc)
lower_series = pd.Series(confint[:, 0], index=index_of_fc)
upper_series = pd.Series(confint[:, 1], index=index_of_fc)
# Plot
compare = stock.data["Close"][-200:].reset_index()
plt.plot(train)
# plt.plot(compare["Close"][-30:], color='yellow')
plt.plot(fc_series, color='darkgreen')
plt.fill_between(lower_series.index, 
                 lower_series, 
                 upper_series, 
                 color='k', alpha=.15)
plt.title("1 month "+tickerInput+" forecast - 95% confidence interval")
plt.show()
AbsReward=confint[-1, 1]
AbsRisk=confint[-1, 0]
BuyPrice=compare["Close"].iloc[-1]
Risk=(BuyPrice-AbsRisk)/BuyPrice*100
Reward=(AbsReward-BuyPrice)/BuyPrice*100
RR=Reward/Risk
print("Buy price: ",compare["Close"].iloc[-1])
print("Risk: ",Risk,"%")
print("Reward: ",Reward,"%")
print("R/R: ",RR)
print("Stop loss at < ",AbsRisk)
# Out:
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=655.453, Time=0.01 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=657.324, Time=0.03 sec
#  ARIMA(0,1,2)(0,0,0)[0] intercept   : AIC=659.321, Time=0.03 sec
#  ARIMA(0,1,3)(0,0,0)[0] intercept   : AIC=659.828, Time=0.05 sec
#  ARIMA(0,1,4)(0,0,0)[0] intercept   : AIC=660.948, Time=0.06 sec
#  ARIMA(0,1,5)(0,0,0)[0] intercept   : AIC=662.634, Time=0.09 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=657.322, Time=0.02 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=658.410, Time=0.21 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=660.021, Time=0.12 sec
#  ARIMA(1,1,3)(0,0,0)[0] intercept   : AIC=660.391, Time=0.20 sec
#  ARIMA(1,1,4)(0,0,0)[0] intercept   : AIC=660.282, Time=0.14 sec
#  ARIMA(2,1,0)(0,0,0)[0] intercept   : AIC=659.309, Time=0.03 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=660.113, Time=0.15 sec
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=662.262, Time=0.17 sec
#  ARIMA(2,1,3)(0,0,0)[0] intercept   : AIC=657.512, Time=0.43 sec
#  ARIMA(3,1,0)(0,0,0)[0] intercept   : AIC=659.288, Time=0.04 sec
#  ARIMA(3,1,1)(0,0,0)[0] intercept   : AIC=660.521, Time=0.12 sec
#  ARIMA(3,1,2)(0,0,0)[0] intercept   : AIC=662.514, Time=0.20 sec
#  ARIMA(4,1,0)(0,0,0)[0] intercept   : AIC=660.495, Time=0.06 sec
#  ARIMA(4,1,1)(0,0,0)[0] intercept   : AIC=660.543, Time=0.22 sec
#  ARIMA(5,1,0)(0,0,0)[0] intercept   : AIC=662.156, Time=0.07 sec
#
# Best model:  ARIMA(0,1,0)(0,0,0)[0] intercept
# Total fit time: 2.478 seconds
# Buy price:  66.9000015258789
# Risk:  13.050667388950291 %
# Reward:  19.53227546624089 %
# R/R:  1.4966495493386363
# Stop loss at <  58.16910484353378

# %%
# print(chosen)
# chosen.to_excel('smaRussel.xlsx')
print(chosen.sort_values(by=["R/R"]))
# print(chosen)
# Out:
#          R/R Ticker
# 21  1.511960   MTDR
# 26  1.525658     WD
# 30  1.526643    FBP
# 32  1.537582   SEAS
# 2   1.540680   STAG
# 10  1.541912   UMBF
# 27  1.552555   BCRX
# 39  1.553609    MGY
# 7   1.561778   TRNO
# 43  1.563882    WHD
# 25  1.569080    PBH
# 14  1.575768   SFBS
# 0   1.576145    THC
# 36  1.590231    CNS
# 24  1.594461    GPI
# 42  1.601602   PRGS
# 44  1.607519    CXP
# 17  1.607960    HRI
# 4   1.626105    CHK
# 11  1.633080   PDCE
# 23  1.643796   CATY
# 6   1.649626   ASGN
# 1   1.655227    EGP
# 34  1.655902    CVA
# 33  1.665630    CRC
# 20  1.668146    FHI
# 31  1.680695   COOP
# 19  1.681414     VG
# 37  1.696011   TWNK
# 35  1.703108   OTTR
# 18  1.762686    MUR
# 28  1.782157    MIC
# 29  1.806490   INOV
# 5   1.822554    KBR
# 3   1.893945    OVV
# 8   1.897710    WTS
# 9   1.963520    NSA
# 38  2.037114    IRT
# 41  2.066140   ROIC
# 16  2.077923    HGV
# 15  2.170996   MIME
# 40  2.569456    MFA
# 13  2.607235   MUSA
# 45  2.812941    LNN
# 22  2.863567   APAM
# 12  3.422442   ALRM
# 46  8.624259    SJW
